# %%
import pandas as pd
import numpy as np
import pymysql
import mysql.connector

# %%
myconn = mysql.connector.connect(host="localhost", user="root" ,passwd="pawan",database="student")
cur = myconn.cursor()
try:
    dbs = cur.execute("show databases")
except:
    myconn.rollback()
for x in cur:
    print(x)
myconn.close()
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('student',)
# ('sys',)
# ('world',)

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:pawan@localhost:3306/student')

# %%
df = pd.read_sql_table("student_marks",engine)
df
# Out:
#        name gender         dob maths physics chemistry english biology  \
# 0      John      M  05-04-1988    55      45        56      87      21
# 1    Suresh      M  04-05-1987    75      96        78      64      90
# 2    Ramesh      M  25-05-1989    25      54        89      76      95
# 3   Jessica      F  12-08-1990    78      96        86      63      54
# 4  Jennifer      F  02-09-1989    58      96        78      46      96
# 5      Annu      F  05-04-1988    45      87        52      89      55
# 6     pooja      F  04-05-1987    55      64        61      58      75
# 7    Ritesh      M  25-05-1989    54      76        87      56      25
# 8     Farha      F  12-08-1990    55      63        89      75      78
# 9    Mukesh      M  02-09-1989    96      46        77      83      58
#
#   economics history civics
# 0        52      89     65
# 1        61      58      2
# 2        87      56     74
# 3        89      75     45
# 4        77      83     53
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#        name gender         dob maths physics chemistry english biology  \
# 0      John      M  05-04-1988    55      45        56      87      21
# 1    Suresh      M  04-05-1987    75      96        78      64      90
# 2    Ramesh      M  25-05-1989    25      54        89      76      95
# 3   Jessica      F  12-08-1990    78      96        86      63      54
# 4  Jennifer      F  02-09-1989    58      96        78      46      96
#
#   economics history civics
# 0        52      89     65
# 1        61      58      2
# 2        87      56     74
# 3        89      75     45
# 4        77      83     53

# %%
df.describe()
# Out:
#          name gender         dob maths physics chemistry english biology  \
# count      10     10          10    10      10        10      10      10
# unique     10      2           5     8       8         8      10      10
# top     pooja      F  12-08-1990    55      96        89      83      95
# freq        1      5           2     3       3         2       1       1
#
#        economics history civics
# count         10      10     10
# unique         9      10     10
# top           89      83     74
# freq           2       1      1

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a98a4ca2e502> in <module>
#       1 attributes=["name","maths","physics","english","cicics"]
# ----> 2 scatter_matrix(df[attributes],figsize=(20,20))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
